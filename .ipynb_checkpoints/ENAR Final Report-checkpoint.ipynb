# %%
# Load Library

packages <- c("dplyr", "haven","ggplot2")

install_if_missing <- function(pkg) {
  if (!requireNamespace(pkg, quietly = TRUE)) {
    install.packages(pkg)
  }
  library(pkg, character.only = TRUE)
}

lapply(packages, install_if_missing)

#test
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# [[1]]
# [1] "dplyr"     "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
# [1] "haven"     "dplyr"     "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "ggplot2"   "haven"     "dplyr"     "stats"     "graphics"  "grDevices"
#  [7] "utils"     "datasets"  "methods"   "base"

# %% [markdown]
# # Read Data

# %% [markdown]
# ## Selected Variables

# %%
var9902 <- readLines("Data/var9902.txt") # Selected Variable for Diet
length(var9902)
var0304 <- readLines("Data/var0304.txt") # Selected Variable for Diet
length(var0304)
var0520 <- readLines("Data/var0520.txt") # Selected Variable for Diet
length(var0520)

var_nhanes <- readLines("Data/Nhanes_Variables.txt") # Selected Variable for Nhanes
length(var_nhanes)
# Out:
# Warning message in readLines("Data/var9902.txt"):
# "incomplete final line found on 'Data/var9902.txt'"
# [1] 46
# Warning message in readLines("Data/var0304.txt"):
# "incomplete final line found on 'Data/var0304.txt'"
# [1] 46
# Warning message in readLines("Data/var0520.txt"):
# "incomplete final line found on 'Data/var0520.txt'"
# [1] 46
# Warning message in readLines("Data/Nhanes_Variables.txt"):
# "incomplete final line found on 'Data/Nhanes_Variables.txt'"
# [1] 12

# %% [markdown]
# ## Read Nhanes Data

# %%
nahnes <- read.csv("Data/nhanes_data.csv") %>% 
    select(all_of(var_nhanes))
head(nahnes)
# Out:
#   svy_id svy_year  demo_age_cat demo_race          demo_race_black
# 1 12     1999-2000 18 to 44     Non-Hispanic White No
# 2 21     1999-2000 18 to 44     Hispanic           No
# 3 27     1999-2000 18 to 44     Hispanic           No
# 4 28     1999-2000 18 to 44     Non-Hispanic White No
# 5 56     1999-2000 18 to 44     Non-Hispanic White No
# 6 57     1999-2000 18 to 44     Non-Hispanic White No
#   demo_age_years demo_pregnant demo_gender bp_sys_mean bp_dia_mean cc_bmi
# 1 37             No            Men         176.6667    102.00000   30 to <35
# 2 18             No            Men         121.3333     80.00000   35+
# 3 18             No            Men         118.0000     78.00000   25 to <30
# 4 18             No            Men          94.0000     42.66667   <25
# 5 21             No            Men         121.0000     65.00000   <25
# 6 39             No            Men         119.3333     85.33333   25 to <30
#   htn_aware
# 1 Yes
# 2 No
# 3 No
# 4 No
# 5 No
# 6 Yes

# %% [markdown]
# ## Read DT1TOT Data

# %%
# DR1TOT
tot <- data.frame() 

## DR1TOT_A Have different water variable name, rename it
tot_a <- read_xpt("Data/DR1TOT_A.xpt")
names(tot_a)[names(tot_a) == "DRXTWATE"] <- "DRXTMOIS"
tot_a <- tot_a  %>% 
    select(all_of(var9902))

tot <- rbind(tot, tot_a)


## DR1TOT_B
tot_b <- read_xpt("Data/DR1TOT_B.xpt")
tot_b <- tot_b  %>% 
    select(all_of(var9902))

tot <- rbind(tot, tot_b)


## DR1TOT_C
tot_c <- read_xpt("Data/DR1TOT_C.xpt")
tot_c <- tot_c  %>% 
    select(all_of(var0304))
names(tot_c) <- var9902 # Same Vairbale Name

tot <- rbind(tot, tot_c)


## DR1TOT_D to DR1TOT_J
files <- paste0("Data/DR1TOT_", LETTERS[4:10], ".xpt")  

for (file in files) {
    temp <- read_xpt(file) %>%
        select(all_of(var0520))
    
    names(temp) <- var9902  #Same Vairbale Name
    
    tot <- rbind(tot, temp) 
}

# View Data
head(tot)
tail(tot)
# Out:
#   SEQN DRXTPROT DRXTCARB DRXTTFAT DRXTSFAT DRXTMFAT DRXTPFAT DRXTCHOL DRXTFIBE
# 1 1     31.96   250.36    27.24    9.40     9.00     6.40     46.55    7.41
# 2 2    123.16   350.37    71.95   24.34    26.48    11.94    313.95   36.99
# 3 3     40.19   233.63    49.94   15.61    19.57    11.84     86.22   11.16
# 4 4     56.16   191.03    56.20   27.54    20.13     4.67    194.78    5.45
# 5 5     97.13   253.98   114.52   36.00    60.55    11.35    180.57   17.28
# 6 6     24.63   202.11    25.15    7.78     7.84     7.15     38.45    6.24
#   DRXTVB6 ⋯ DRXTM201 DRXTM221 DRXTP182 DRXTP183 DRXTP184 DRXTP204 DRXTP205
# 1 1.43    ⋯ 0.03     0.00      6.07    0.27     0        0.03     0.00
# 2 2.90    ⋯ 0.09     0.02     10.07    1.14     0        0.26     0.00
# 3 1.37    ⋯ 0.16     0.00     11.12    0.55     0        0.07     0.01
# 4 0.95    ⋯ 0.05     0.14      3.96    0.66     0        0.05     0.00
# 5 2.92    ⋯ 0.18     0.00     10.03    1.25     0        0.07     0.00
# 6 0.97    ⋯ 0.05     0.01      6.41    0.69     0        0.03     0.00
#   DRXTP225 DRXTP226 DRD320GW
# 1 0.00     0.00      243.38
# 2 0.01     0.02        0.00
# 3 0.02     0.03      531.00
# 4 0.00     0.00     1652.00
# 5 0.01     0.01     1298.00
# 6 0.00     0.00     1711.00
#   SEQN   DRXTPROT DRXTCARB DRXTTFAT DRXTSFAT DRXTMFAT DRXTPFAT DRXTCHOL
# 1 124817  51.33    90.33    63.18   25.360   22.624    9.509   813
# 2 124818  58.05   512.14   183.51   62.115   61.034   45.841   220
# 3 124819  67.43   197.26    77.71   32.515   24.228   10.880   175
# 4 124820  39.32   157.81    48.77   15.558   13.070   14.765    84
# 5 124821 138.10   110.59    76.03   15.733   30.469   20.797   484
# 6 124822     NA       NA       NA       NA       NA       NA    NA
#   DRXTFIBE DRXTVB6 ⋯ DRXTM201 DRXTM221 DRXTP182 DRXTP183 DRXTP184 DRXTP204
# 1  5.8     0.691   ⋯ 0.106    0.000     8.038   0.832    0.001    0.392
# 2 15.0     0.647   ⋯ 0.444    0.004    41.362   4.263    0.000    0.088
# 3  8.3     1.421   ⋯ 0.164    0.001     9.937   0.981    0.002    0.070
# 4 12.3     2.002   ⋯ 0.138    0.004    13.410   1.293    0.002    0.042
# 5  6.7     1.688   ⋯ 0.546    0.020    17.314   1.944    0.009    0.309
# 6   NA        NA   ⋯    NA       NA        NA      NA       NA       NA
#   DRXTP205 DRXTP225 DRXTP226 DRD320GW
# 1 0.003    0.025    0.111    1521.0
# 2 0.010    0.019    0.006       0.0
# 3 0.007    0.018    0.003     225.0
# 4 0.007    0.009    0.001       0.0
# 5 0.124    0.090    0.350    1267.5
# 6    NA       NA       NA        NA

# %% [markdown]
# ## Merge Nhanes and DT1TOT

# %%
merge_df <- merge(nahnes, tot, by.x = "svy_id", by.y = "SEQN")

head(merge_df)
tail(merge_df)
# Out:
#   svy_id svy_year  demo_age_cat demo_race          demo_race_black
# 1  2     1999-2000 75+          Non-Hispanic White No
# 2  5     1999-2000 45 to 64     Non-Hispanic White No
# 3  6     1999-2000 18 to 44     Other              No
# 4  7     1999-2000 45 to 64     Non-Hispanic Black Yes
# 5 10     1999-2000 18 to 44     Non-Hispanic Black Yes
# 6 12     1999-2000 18 to 44     Non-Hispanic White No
#   demo_age_years demo_pregnant demo_gender bp_sys_mean bp_dia_mean ⋯ DRXTM201
# 1 77             No            Men         100.6667     56.66667   ⋯ 0.09
# 2 49             No            Men         122.0000     82.66667   ⋯ 0.18
# 3 19             No            Women       114.6667     68.00000   ⋯ 0.05
# 4 59             No            Women       125.3333     80.00000   ⋯ 0.08
# 5 43             No            Men         145.3333     96.00000   ⋯ 0.20
# 6 37             No            Men         176.6667    102.00000   ⋯ 0.31
#   DRXTM221 DRXTP182 DRXTP183 DRXTP184 DRXTP204 DRXTP205 DRXTP225 DRXTP226
# 1 0.02     10.07    1.14     0.00     0.26     0.00     0.01     0.02
# 2 0.00     10.03    1.25     0.00     0.07     0.00     0.01     0.01
# 3 0.01      6.41    0.69     0.00     0.03     0.00     0.00     0.00
# 4 0.01     15.31    2.23     0.06     0.13     0.15     0.03     0.20
# 5 0.01     12.73    2.06     0.00     0.28     0.00     0.00     0.00
# 6 0.33     35.46    3.46     0.00     0.49     0.01     0.00     0.09
#   DRD320GW
# 1    0
# 2 1298
# 3 1711
# 4  236
# 5 1888
# 6 3304
#       svy_id svy_year  demo_age_cat demo_race          demo_race_black
# 59794 124814 2017-2020 45 to 64     Non-Hispanic Black Yes
# 59795 124815 2017-2020 45 to 64     Non-Hispanic Black Yes
# 59796 124817 2017-2020 65 to 74     Hispanic           No
# 59797 124818 2017-2020 18 to 44     Non-Hispanic Black Yes
# 59798 124821 2017-2020 45 to 64     Non-Hispanic Black Yes
# 59799 124822 2017-2020 65 to 74     Hispanic           No
#       demo_age_years demo_pregnant demo_gender bp_sys_mean bp_dia_mean ⋯
# 59794 64             No            Men         140.1667    85.36667    ⋯
# 59795 52             No            Men         141.5000    85.36667    ⋯
# 59796 67             No            Women       113.5000    66.03333    ⋯
# 59797 40             No            Men         104.5000    66.03333    ⋯
# 59798 63             No            Men         125.5000    65.36667    ⋯
# 59799 74             No            Men         123.5000    55.03333    ⋯
#       DRXTM201 DRXTM221 DRXTP182 DRXTP183 DRXTP184 DRXTP204 DRXTP205 DRXTP225
# 59794 0.211    0.008    16.079   1.911    0.000    0.085    0.005    0.009
# 59795 0.403    0.066    13.748   1.040    0.106    0.455    0.008    0.030
# 59796 0.106    0.000     8.038   0.832    0.001    0.392    0.003    0.025
# 59797 0.444    0.004    41.362   4.263    0.000    0.088    0.010    0.019
# 59798 0.546    0.020    17.314   1.944    0.009    0.309    0.124    0.090
# 59799    NA       NA        NA      NA       NA       NA       NA       NA
#       DRXTP226 DRD320GW
# 59794 0.005    1014.0
# 59795 0.093    2028.0
# 59796 0.111    1521.0
# 59797 0.006       0.0
# 59798 0.350    1267.5
# 59799    NA        NA

# %% [markdown]
# ## cleaning the data

# %%
##' exclude pregnant women and missing responses on bp
merge_df <- merge_df %>% 
  filter(demo_pregnant == "No") %>% 
  filter(!is.na(bp_sys_mean) & !is.na(bp_dia_mean))

# %% [markdown]
# Tried locally that most missing values are missing together as an observation for all year cycle. Specifically, those variables missing together are the ones that represent types of fatty acids. `cc_bmi` and `DRD320GW` have missing indexes partially overlapping with the acids.
# And no variable is missing more than 10% of the total sample size of the year cycle. So the complete merged data set can be imputed using the union of indexes of all year cycles.

# %%
# together:
ms_idx<- lapply(names(merge_df), function(col) which(is.na(merge_df[[col]])))
names(ms_idx) <- names(merge_df)
ms_idx_len <- lapply(ms_idx, length)

# delete the union of the indexes
mid_u <- union(ms_idx$DRD320GW, ms_idx$DRXTP226)
union_idx <- union(ms_idx$cc_bmi, mid_u)
merge_df_cln <- merge_df[-union_idx,]
# check: get the missing value indexes again
ms_idx_cln <- lapply(names(merge_df_cln), function(col) which(is.na(merge_df_cln[[col]])))
names(ms_idx_cln) <- names(merge_df_cln)
ms_idx_cln_len <- lapply(ms_idx_cln, length)

# %%
# print the length of missing values for each variable
print(ms_idx_cln_len > 0)
# Out:
#          svy_id        svy_year    demo_age_cat       demo_race demo_race_black
#           FALSE           FALSE           FALSE           FALSE           FALSE
#  demo_age_years   demo_pregnant     demo_gender     bp_sys_mean     bp_dia_mean
#           FALSE           FALSE           FALSE           FALSE           FALSE
#          cc_bmi       htn_aware        DRXTPROT        DRXTCARB        DRXTTFAT
#           FALSE            TRUE           FALSE           FALSE           FALSE
#        DRXTSFAT        DRXTMFAT        DRXTPFAT        DRXTCHOL        DRXTFIBE
#           FALSE           FALSE           FALSE           FALSE           FALSE
#         DRXTVB6        DRXTVB12        DRXTFOLA          DRXTVC        DRXTCALC
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTPHOS        DRXTMAGN        DRXTIRON        DRXTZINC        DRXTCOPP
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRDTSODI        DRXTPOTA        DRXTSELE        DRXTCAFF        DRXTTHEO
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTALCO        DRXTMOIS        DRXTS040        DRXTS060        DRXTS080
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTS100        DRXTS120        DRXTS140        DRXTS160        DRXTS180
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTM161        DRXTM181        DRXTM201        DRXTM221        DRXTP182
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTP183        DRXTP184        DRXTP204        DRXTP205        DRXTP225
#           FALSE           FALSE           FALSE           FALSE           FALSE
#        DRXTP226        DRD320GW
#           FALSE           FALSE

# %%
# write.csv(merge_df_cln, "Data/merge_df_cln.csv")

# %% [markdown]
# # EDA and univariate analysis

# %%
summary(merge_df_cln)
# Out:
#      svy_id         svy_year         demo_age_cat        demo_race
#  Min.   :     2   Length:50563       Length:50563       Length:50563
#  1st Qu.: 30064   Class :character   Class :character   Class :character
#  Median : 56211   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 58259
#  3rd Qu.: 82919
#  Max.   :124821
#  demo_race_black    demo_age_years  demo_pregnant      demo_gender
#  Length:50563       Min.   :18.00   Length:50563       Length:50563
#  Class :character   1st Qu.:31.00   Class :character   Class :character
#  Mode  :character   Median :47.00   Mode  :character   Mode  :character
#                     Mean   :47.75
#                     3rd Qu.:63.00
#                     Max.   :80.00
#   bp_sys_mean      bp_dia_mean        cc_bmi           htn_aware
#  Min.   : 64.67   Min.   :  8.00   Length:50563       Length:50563
#  1st Qu.:111.33   1st Qu.: 63.33   Class :character   Class :character
#  Median :121.17   Median : 70.67   Mode  :character   Mode  :character
#  Mean   :124.36   Mean   : 70.68
#  3rd Qu.:134.00   3rd Qu.: 78.00
#  Max.   :270.00   Max.   :133.70
#     DRXTPROT         DRXTCARB         DRXTTFAT         DRXTSFAT
#  Min.   :  0.00   Min.   :   0.0   Min.   :  0.00   Min.   :  0.00
#  1st Qu.: 51.66   1st Qu.: 169.0   1st Qu.: 47.85   1st Qu.: 14.49
#  Median : 72.95   Median : 235.3   Median : 71.85   Median : 22.63
#  Mean   : 80.79   Mean   : 258.2   Mean   : 80.84   Mean   : 26.20
#  3rd Qu.:100.62   3rd Qu.: 320.3   3rd Qu.:103.44   3rd Qu.: 34.07
#  Max.   :718.42   Max.   :1815.0   Max.   :839.65   Max.   :268.59
#     DRXTMFAT         DRXTPFAT         DRXTCHOL         DRXTFIBE
#  Min.   :  0.00   Min.   :  0.00   Min.   :   0.0   Min.   :  0.00
#  1st Qu.: 16.73   1st Qu.:  9.57   1st Qu.: 129.0   1st Qu.:  9.10
#  Median : 25.66   Median : 15.30   Median : 225.0   Median : 14.00
#  Mean   : 29.26   Mean   : 18.04   Mean   : 296.7   Mean   : 16.22
#  3rd Qu.: 37.68   3rd Qu.: 23.38   3rd Qu.: 394.0   3rd Qu.: 20.80
#  Max.   :339.93   Max.   :218.70   Max.   :3092.7   Max.   :147.60
#     DRXTVB6          DRXTVB12          DRXTFOLA          DRXTVC
#  Min.   : 0.000   Min.   :  0.000   Min.   :   0.0   Min.   :   0.0
#  1st Qu.: 1.111   1st Qu.:  2.030   1st Qu.: 226.0   1st Qu.:  21.7
#  Median : 1.667   Median :  3.650   Median : 336.0   Median :  54.4
#  Mean   : 1.983   Mean   :  5.008   Mean   : 388.7   Mean   :  87.1
#  3rd Qu.: 2.430   3rd Qu.:  6.120   3rd Qu.: 489.0   3rd Qu.: 118.7
#  Max.   :48.321   Max.   :381.080   Max.   :4803.0   Max.   :2261.0
#     DRXTCALC          DRXTPHOS        DRXTMAGN         DRXTIRON
#  Min.   :    0.0   Min.   :    0   Min.   :   0.0   Min.   :  0.00
#  1st Qu.:  488.0   1st Qu.:  859   1st Qu.: 185.4   1st Qu.:  8.86
#  Median :  767.0   Median : 1202   Median : 260.0   Median : 12.78
#  Mean   :  890.7   Mean   : 1322   Mean   : 287.3   Mean   : 14.70
#  3rd Qu.: 1141.0   3rd Qu.: 1648   3rd Qu.: 357.0   3rd Qu.: 18.31
#  Max.   :11448.0   Max.   :11529   Max.   :2725.0   Max.   :147.88
#     DRXTZINC         DRXTCOPP         DRDTSODI        DRXTPOTA
#  Min.   :  0.00   Min.   : 0.000   Min.   :    0   Min.   :    0
#  1st Qu.:  6.50   1st Qu.: 0.767   1st Qu.: 2155   1st Qu.: 1706
#  Median :  9.61   Median : 1.083   Median : 3076   Median : 2398
#  Mean   : 11.30   Mean   : 1.251   Mean   : 3419   Mean   : 2602
#  3rd Qu.: 14.02   3rd Qu.: 1.507   3rd Qu.: 4278   3rd Qu.: 3257
#  Max.   :585.47   Max.   :59.605   Max.   :25949   Max.   :19175
#     DRXTSELE         DRXTCAFF          DRXTTHEO          DRXTALCO
#  Min.   :   0.0   Min.   :   0.00   Min.   :   0.00   Min.   :   0.00
#  1st Qu.:  67.9   1st Qu.:   9.43   1st Qu.:   0.00   1st Qu.:   0.00
#  Median :  98.2   Median :  93.00   Median :   0.00   Median :   0.00
#  Mean   : 110.7   Mean   : 149.82   Mean   :  35.45   Mean   :  10.04
#  3rd Qu.: 138.4   3rd Qu.: 206.00   3rd Qu.:  37.00   3rd Qu.:   0.00
#  Max.   :1265.9   Max.   :5151.00   Max.   :2038.00   Max.   :1152.80
#     DRXTMOIS        DRXTS040         DRXTS060         DRXTS080
#  Min.   :    0   Min.   :0.0000   Min.   :0.0000   Min.   : 0.0000
#  1st Qu.: 1620   1st Qu.:0.1320   1st Qu.:0.0790   1st Qu.: 0.0700
#  Median : 2319   Median :0.3520   Median :0.2040   Median : 0.1650
#  Mean   : 2625   Mean   :0.4969   Mean   :0.2872   Mean   : 0.2385
#  3rd Qu.: 3267   3rd Qu.:0.6950   3rd Qu.:0.4000   3rd Qu.: 0.3190
#  Max.   :18266   Max.   :9.3900   Max.   :5.6340   Max.   :10.8170
#     DRXTS100          DRXTS120          DRXTS140         DRXTS160
#  Min.   : 0.0000   Min.   : 0.0000   Min.   : 0.000   Min.   :  0.000
#  1st Qu.: 0.1430   1st Qu.: 0.1920   1st Qu.: 0.850   1st Qu.:  8.152
#  Median : 0.3300   Median : 0.4420   Median : 1.687   Median : 12.551
#  Mean   : 0.4479   Mean   : 0.7831   Mean   : 2.152   Mean   : 14.354
#  3rd Qu.: 0.6160   3rd Qu.: 0.8820   3rd Qu.: 2.900   3rd Qu.: 18.500
#  Max.   :10.7270   Max.   :63.7500   Max.   :37.283   Max.   :129.323
#     DRXTS180         DRXTM161         DRXTM181         DRXTM201
#  Min.   : 0.000   Min.   : 0.000   Min.   :  0.00   Min.   : 0.0000
#  1st Qu.: 3.561   1st Qu.: 0.587   1st Qu.: 15.51   1st Qu.: 0.1100
#  Median : 5.696   Median : 1.008   Median : 23.86   Median : 0.2020
#  Mean   : 6.583   Mean   : 1.231   Mean   : 27.25   Mean   : 0.2707
#  3rd Qu.: 8.579   3rd Qu.: 1.613   3rd Qu.: 35.10   3rd Qu.: 0.3460
#  Max.   :61.594   Max.   :22.880   Max.   :328.84   Max.   :18.1190
#     DRXTM221           DRXTP182          DRXTP183         DRXTP184
#  Min.   : 0.00000   Min.   :  0.000   Min.   : 0.000   Min.   :0.00000
#  1st Qu.: 0.00100   1st Qu.:  8.319   1st Qu.: 0.800   1st Qu.:0.00000
#  Median : 0.00700   Median : 13.452   Median : 1.310   Median :0.00000
#  Mean   : 0.03425   Mean   : 15.932   Mean   : 1.622   Mean   :0.01092
#  3rd Qu.: 0.02800   3rd Qu.: 20.689   3rd Qu.: 2.067   3rd Qu.:0.00300
#  Max.   :25.31500   Max.   :195.387   Max.   :38.127   Max.   :0.92700
#     DRXTP204         DRXTP205          DRXTP225          DRXTP226
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.00000   Min.   :0.0000
#  1st Qu.:0.0570   1st Qu.:0.00100   1st Qu.:0.00100   1st Qu.:0.0020
#  Median :0.1130   Median :0.00600   Median :0.01100   Median :0.0170
#  Mean   :0.1497   Mean   :0.03817   Mean   :0.02253   Mean   :0.0738
#  3rd Qu.:0.2030   3rd Qu.:0.01600   3rd Qu.:0.02600   3rd Qu.:0.0600
#  Max.   :3.0080   Max.   :4.11400   Max.   :2.42700   Max.   :8.7170
#     DRD320GW
#  Min.   :    0
#  1st Qu.:  240
#  Median :  826
#  Mean   : 1098
#  3rd Qu.: 1570
#  Max.   :16727

# %%
# define a function that calculate summary statistics for numerical variables and levels for characteristics ones
# returns a list `statistic` that contains the results and
# returns a modified data set that converted the characteristics to factors
calculate_stats <- function(data) {
  # Load necessary packages
  if (!requireNamespace("dplyr", quietly = TRUE)) install.packages("dplyr")
  if (!requireNamespace("modeest", quietly = TRUE)) install.packages("modeest")

  library(dplyr)
  library(modeest)

  # Initialize an empty list to store results
  results <- list()
  
  # Iterate through each column
  for (col_name in colnames(data)) {
    column <- data[[col_name]]
    
    if (is.numeric(column)) {
      # Calculate mean, median, mode, and standard deviation
      mean_value <- mean(column)
      median_value <- median(column)
      min_value <- min(column)
      max_value <- max(column)
      #mode_value <- as.numeric(mlv(na.omit(column), method = "mfv"))
      sd_value <- sd(column)
      
      # Store results in a sublist
      results[[col_name]] <- list(
        type = "numeric",
        mean = mean_value,
        median = median_value,
        minimum = min_value,
          maximum = max_value,
        #mode = mode_value,
        std_dev = sd_value
      )
      
    } else {
      # Convert character columns to factors
      data[[col_name]] <- as.factor(column)
      
      # Calculate frequency table for categorical variables
      freq_table <- table(data[[col_name]])
      
      # Store results in a sublist
      results[[col_name]] <- list(
        type = "categorical",
        frequencies = as.list(freq_table)
      )
    }
  }
  
  # Return both the computed statistics and the modified dataset
  return(list(statistics = results, modified_data = data))
}

# %%
# leave the survey id (svy_id) out
result <- calculate_stats(merge_df_cln[,-c(1)])

# %%
result$statistics
# Out:
# $svy_year
# $svy_year$type
# [1] "categorical"
#
# $svy_year$frequencies
# $svy_year$frequencies$`1999-2000`
# [1] 4208
#
# $svy_year$frequencies$`2001-2002`
# [1] 4532
#
# $svy_year$frequencies$`2003-2004`
# [1] 4352
#
# $svy_year$frequencies$`2005-2006`
# [1] 4419
#
# $svy_year$frequencies$`2007-2008`
# [1] 5325
#
# $svy_year$frequencies$`2009-2010`
# [1] 5686
#
# $svy_year$frequencies$`2011-2012`
# [1] 4750
#
# $svy_year$frequencies$`2013-2014`
# [1] 5037
#
# $svy_year$frequencies$`2015-2016`
# [1] 4978
#
# $svy_year$frequencies$`2017-2020`
# [1] 7276
#
#
#
# $demo_age_cat
# $demo_age_cat$type
# [1] "categorical"
#
# $demo_age_cat$frequencies
# $demo_age_cat$frequencies$`18 to 44`
# [1] 22945
#
# $demo_age_cat$frequencies$`45 to 64`
# [1] 16029
#
# $demo_age_cat$frequencies$`65 to 74`
# [1] 6508
#
# $demo_age_cat$frequencies$`75+`
# [1] 5081
#
#
#
# $demo_race
# $demo_race$type
# [1] "categorical"
#
# $demo_race$frequencies
# $demo_race$frequencies$Hispanic
# [1] 13115
#
# $demo_race$frequencies$`Non-Hispanic Asian`
# [1] 2413
#
# $demo_race$frequencies$`Non-Hispanic Black`
# [1] 11069
#
# $demo_race$frequencies$`Non-Hispanic White`
# [1] 22010
#
# $demo_race$frequencies$Other
# [1] 1956
#
#
#
# $demo_race_black
# $demo_race_black$type
# [1] "categorical"
#
# $demo_race_black$frequencies
# $demo_race_black$frequencies$No
# [1] 39494
#
# $demo_race_black$frequencies$Yes
# [1] 11069
#
#
#
# $demo_age_years
# $demo_age_years$type
# [1] "numeric"
#
# $demo_age_years$mean
# [1] 47.75019
#
# $demo_age_years$median
# [1] 47
#
# $demo_age_years$minimum
# [1] 18
#
# $demo_age_years$maximum
# [1] 80
#
# $demo_age_years$std_dev
# [1] 18.87903
#
#
# $demo_pregnant
# $demo_pregnant$type
# [1] "categorical"
#
# $demo_pregnant$frequencies
# $demo_pregnant$frequencies$No
# [1] 50563
#
#
#
# $demo_gender
# $demo_gender$type
# [1] "categorical"
#
# $demo_gender$frequencies
# $demo_gender$frequencies$Men
# [1] 25516
#
# $demo_gender$frequencies$Women
# [1] 25047
#
#
#
# $bp_sys_mean
# $bp_sys_mean$type
# [1] "numeric"
#
# $bp_sys_mean$mean
# [1] 124.3648
#
# $bp_sys_mean$median
# [1] 121.1667
#
# $bp_sys_mean$minimum
# [1] 64.66667
#
# $bp_sys_mean$maximum
# [1] 270
#
# $bp_sys_mean$std_dev
# [1] 19.07071
#
#
# $bp_dia_mean
# $bp_dia_mean$type
# [1] "numeric"
#
# $bp_dia_mean$mean
# [1] 70.68495
#
# $bp_dia_mean$median
# [1] 70.66667
#
# $bp_dia_mean$minimum
# [1] 8
#
# $bp_dia_mean$maximum
# [1] 133.7
#
# $bp_dia_mean$std_dev
# [1] 11.90995
#
#
# $cc_bmi
# $cc_bmi$type
# [1] "categorical"
#
# $cc_bmi$frequencies
# $cc_bmi$frequencies$`<25`
# [1] 15796
#
# $cc_bmi$frequencies$`25 to <30`
# [1] 16620
#
# $cc_bmi$frequencies$`30 to <35`
# [1] 10120
#
# $cc_bmi$frequencies$`35+`
# [1] 8027
#
#
#
# $htn_aware
# $htn_aware$type
# [1] "categorical"
#
# $htn_aware$frequencies
# $htn_aware$frequencies$No
# [1] 33525
#
# $htn_aware$frequencies$Yes
# [1] 16824
#
#
#
# $DRXTPROT
# $DRXTPROT$type
# [1] "numeric"
#
# $DRXTPROT$mean
# [1] 80.79348
#
# $DRXTPROT$median
# [1] 72.95
#
# $DRXTPROT$minimum
# [1] 0
#
# $DRXTPROT$maximum
# [1] 718.42
#
# $DRXTPROT$std_dev
# [1] 43.31412
#
#
# $DRXTCARB
# $DRXTCARB$type
# [1] "numeric"
#
# $DRXTCARB$mean
# [1] 258.2434
#
# $DRXTCARB$median
# [1] 235.35
#
# $DRXTCARB$minimum
# [1] 0
#
# $DRXTCARB$maximum
# [1] 1815.02
#
# $DRXTCARB$std_dev
# [1] 131.0796
#
#
# $DRXTTFAT
# $DRXTTFAT$type
# [1] "numeric"
#
# $DRXTTFAT$mean
# [1] 80.84467
#
# $DRXTTFAT$median
# [1] 71.85
#
# $DRXTTFAT$minimum
# [1] 0
#
# $DRXTTFAT$maximum
# [1] 839.65
#
# $DRXTTFAT$std_dev
# [1] 47.42065
#
#
# $DRXTSFAT
# $DRXTSFAT$type
# [1] "numeric"
#
# $DRXTSFAT$mean
# [1] 26.2037
#
# $DRXTSFAT$median
# [1] 22.633
#
# $DRXTSFAT$minimum
# [1] 0
#
# $DRXTSFAT$maximum
# [1] 268.591
#
# $DRXTSFAT$std_dev
# [1] 16.95308
#
#
# $DRXTMFAT
# $DRXTMFAT$type
# [1] "numeric"
#
# $DRXTMFAT$mean
# [1] 29.26117
#
# $DRXTMFAT$median
# [1] 25.655
#
# $DRXTMFAT$minimum
# [1] 0
#
# $DRXTMFAT$maximum
# [1] 339.932
#
# $DRXTMFAT$std_dev
# [1] 18.15123
#
#
# $DRXTPFAT
# $DRXTPFAT$type
# [1] "numeric"
#
# $DRXTPFAT$mean
# [1] 18.04031
#
# $DRXTPFAT$median
# [1] 15.3
#
# $DRXTPFAT$minimum
# [1] 0
#
# $DRXTPFAT$maximum
# [1] 218.701
#
# $DRXTPFAT$std_dev
# [1] 12.41565
#
#
# $DRXTCHOL
# $DRXTCHOL$type
# [1] "numeric"
#
# $DRXTCHOL$mean
# [1] 296.7353
#
# $DRXTCHOL$median
# [1] 225
#
# $DRXTCHOL$minimum
# [1] 0
#
# $DRXTCHOL$maximum
# [1] 3092.7
#
# $DRXTCHOL$std_dev
# [1] 246.0828
#
#
# $DRXTFIBE
# $DRXTFIBE$type
# [1] "numeric"
#
# $DRXTFIBE$mean
# [1] 16.22498
#
# $DRXTFIBE$median
# [1] 14
#
# $DRXTFIBE$minimum
# [1] 0
#
# $DRXTFIBE$maximum
# [1] 147.6
#
# $DRXTFIBE$std_dev
# [1] 10.39276
#
#
# $DRXTVB6
# $DRXTVB6$type
# [1] "numeric"
#
# $DRXTVB6$mean
# [1] 1.983185
#
# $DRXTVB6$median
# [1] 1.667
#
# $DRXTVB6$minimum
# [1] 0
#
# $DRXTVB6$maximum
# [1] 48.321
#
# $DRXTVB6$std_dev
# [1] 1.526358
#
#
# $DRXTVB12
# $DRXTVB12$type
# [1] "numeric"
#
# $DRXTVB12$mean
# [1] 5.008543
#
# $DRXTVB12$median
# [1] 3.65
#
# $DRXTVB12$minimum
# [1] 0
#
# $DRXTVB12$maximum
# [1] 381.08
#
# $DRXTVB12$std_dev
# [1] 7.268675
#
#
# $DRXTFOLA
# $DRXTFOLA$type
# [1] "numeric"
#
# $DRXTFOLA$mean
# [1] 388.6828
#
# $DRXTFOLA$median
# [1] 336
#
# $DRXTFOLA$minimum
# [1] 0
#
# $DRXTFOLA$maximum
# [1] 4803
#
# $DRXTFOLA$std_dev
# [1] 246.1195
#
#
# $DRXTVC
# $DRXTVC$type
# [1] "numeric"
#
# $DRXTVC$mean
# [1] 87.10004
#
# $DRXTVC$median
# [1] 54.4
#
# $DRXTVC$minimum
# [1] 0
#
# $DRXTVC$maximum
# [1] 2261
#
# $DRXTVC$std_dev
# [1] 101.5984
#
#
# $DRXTCALC
# $DRXTCALC$type
# [1] "numeric"
#
# $DRXTCALC$mean
# [1] 890.6622
#
# $DRXTCALC$median
# [1] 767
#
# $DRXTCALC$minimum
# [1] 0
#
# $DRXTCALC$maximum
# [1] 11448
#
# $DRXTCALC$std_dev
# [1] 590.2629
#
#
# $DRXTPHOS
# $DRXTPHOS$type
# [1] "numeric"
#
# $DRXTPHOS$mean
# [1] 1322.019
#
# $DRXTPHOS$median
# [1] 1202
#
# $DRXTPHOS$minimum
# [1] 0
#
# $DRXTPHOS$maximum
# [1] 11529
#
# $DRXTPHOS$std_dev
# [1] 683.3428
#
#
# $DRXTMAGN
# $DRXTMAGN$type
# [1] "numeric"
#
# $DRXTMAGN$mean
# [1] 287.2596
#
# $DRXTMAGN$median
# [1] 260
#
# $DRXTMAGN$minimum
# [1] 0
#
# $DRXTMAGN$maximum
# [1] 2725
#
# $DRXTMAGN$std_dev
# [1] 149.6897
#
#
# $DRXTIRON
# $DRXTIRON$type
# [1] "numeric"
#
# $DRXTIRON$mean
# [1] 14.69909
#
# $DRXTIRON$median
# [1] 12.78
#
# $DRXTIRON$minimum
# [1] 0
#
# $DRXTIRON$maximum
# [1] 147.88
#
# $DRXTIRON$std_dev
# [1] 8.830425
#
#
# $DRXTZINC
# $DRXTZINC$type
# [1] "numeric"
#
# $DRXTZINC$mean
# [1] 11.29902
#
# $DRXTZINC$median
# [1] 9.61
#
# $DRXTZINC$minimum
# [1] 0
#
# $DRXTZINC$maximum
# [1] 585.47
#
# $DRXTZINC$std_dev
# [1] 8.896132
#
#
# $DRXTCOPP
# $DRXTCOPP$type
# [1] "numeric"
#
# $DRXTCOPP$mean
# [1] 1.251442
#
# $DRXTCOPP$median
# [1] 1.083
#
# $DRXTCOPP$minimum
# [1] 0
#
# $DRXTCOPP$maximum
# [1] 59.605
#
# $DRXTCOPP$std_dev
# [1] 1.099406
#
#
# $DRDTSODI
# $DRDTSODI$type
# [1] "numeric"
#
# $DRDTSODI$mean
# [1] 3418.887
#
# $DRDTSODI$median
# [1] 3076
#
# $DRDTSODI$minimum
# [1] 0
#
# $DRDTSODI$maximum
# [1] 25949
#
# $DRDTSODI$std_dev
# [1] 1851.809
#
#
# $DRXTPOTA
# $DRXTPOTA$type
# [1] "numeric"
#
# $DRXTPOTA$mean
# [1] 2602.495
#
# $DRXTPOTA$median
# [1] 2398
#
# $DRXTPOTA$minimum
# [1] 0
#
# $DRXTPOTA$maximum
# [1] 19175
#
# $DRXTPOTA$std_dev
# [1] 1292.314
#
#
# $DRXTSELE
# $DRXTSELE$type
# [1] "numeric"
#
# $DRXTSELE$mean
# [1] 110.6522
#
# $DRXTSELE$median
# [1] 98.2
#
# $DRXTSELE$minimum
# [1] 0
#
# $DRXTSELE$maximum
# [1] 1265.86
#
# $DRXTSELE$std_dev
# [1] 65.11818
#
#
# $DRXTCAFF
# $DRXTCAFF$type
# [1] "numeric"
#
# $DRXTCAFF$mean
# [1] 149.8185
#
# $DRXTCAFF$median
# [1] 93
#
# $DRXTCAFF$minimum
# [1] 0
#
# $DRXTCAFF$maximum
# [1] 5151
#
# $DRXTCAFF$std_dev
# [1] 209.223
#
#
# $DRXTTHEO
# $DRXTTHEO$type
# [1] "numeric"
#
# $DRXTTHEO$mean
# [1] 35.44932
#
# $DRXTTHEO$median
# [1] 0
#
# $DRXTTHEO$minimum
# [1] 0
#
# $DRXTTHEO$maximum
# [1] 2038
#
# $DRXTTHEO$std_dev
# [1] 80.21561
#
#
# $DRXTALCO
# $DRXTALCO$type
# [1] "numeric"
#
# $DRXTALCO$mean
# [1] 10.03914
#
# $DRXTALCO$median
# [1] 0
#
# $DRXTALCO$minimum
# [1] 0
#
# $DRXTALCO$maximum
# [1] 1152.8
#
# $DRXTALCO$std_dev
# [1] 29.71664
#
#
# $DRXTMOIS
# $DRXTMOIS$type
# [1] "numeric"
#
# $DRXTMOIS$mean
# [1] 2624.788
#
# $DRXTMOIS$median
# [1] 2318.97
#
# $DRXTMOIS$minimum
# [1] 0
#
# $DRXTMOIS$maximum
# [1] 18266.25
#
# $DRXTMOIS$std_dev
# [1] 1476.508
#
#
# $DRXTS040
# $DRXTS040$type
# [1] "numeric"
#
# $DRXTS040$mean
# [1] 0.4969254
#
# $DRXTS040$median
# [1] 0.352
#
# $DRXTS040$minimum
# [1] 0
#
# $DRXTS040$maximum
# [1] 9.39
#
# $DRXTS040$std_dev
# [1] 0.528036
#
#
# $DRXTS060
# $DRXTS060$type
# [1] "numeric"
#
# $DRXTS060$mean
# [1] 0.287238
#
# $DRXTS060$median
# [1] 0.204
#
# $DRXTS060$minimum
# [1] 0
#
# $DRXTS060$maximum
# [1] 5.634
#
# $DRXTS060$std_dev
# [1] 0.3069467
#
#
# $DRXTS080
# $DRXTS080$type
# [1] "numeric"
#
# $DRXTS080$mean
# [1] 0.2385039
#
# $DRXTS080$median
# [1] 0.165
#
# $DRXTS080$minimum
# [1] 0
#
# $DRXTS080$maximum
# [1] 10.817
#
# $DRXTS080$std_dev
# [1] 0.2811752
#
#
# $DRXTS100
# $DRXTS100$type
# [1] "numeric"
#
# $DRXTS100$mean
# [1] 0.4478961
#
# $DRXTS100$median
# [1] 0.33
#
# $DRXTS100$minimum
# [1] 0
#
# $DRXTS100$maximum
# [1] 10.727
#
# $DRXTS100$std_dev
# [1] 0.4492276
#
#
# $DRXTS120
# $DRXTS120$type
# [1] "numeric"
#
# $DRXTS120$mean
# [1] 0.7831176
#
# $DRXTS120$median
# [1] 0.442
#
# $DRXTS120$minimum
# [1] 0
#
# $DRXTS120$maximum
# [1] 63.75
#
# $DRXTS120$std_dev
# [1] 1.352155
#
#
# $DRXTS140
# $DRXTS140$type
# [1] "numeric"
#
# $DRXTS140$mean
# [1] 2.151683
#
# $DRXTS140$median
# [1] 1.687
#
# $DRXTS140$minimum
# [1] 0
#
# $DRXTS140$maximum
# [1] 37.283
#
# $DRXTS140$std_dev
# [1] 1.888317
#
#
# $DRXTS160
# $DRXTS160$type
# [1] "numeric"
#
# $DRXTS160$mean
# [1] 14.3538
#
# $DRXTS160$median
# [1] 12.551
#
# $DRXTS160$minimum
# [1] 0
#
# $DRXTS160$maximum
# [1] 129.323
#
# $DRXTS160$std_dev
# [1] 8.934903
#
#
# $DRXTS180
# $DRXTS180$type
# [1] "numeric"
#
# $DRXTS180$mean
# [1] 6.582558
#
# $DRXTS180$median
# [1] 5.696
#
# $DRXTS180$minimum
# [1] 0
#
# $DRXTS180$maximum
# [1] 61.594
#
# $DRXTS180$std_dev
# [1] 4.316506
#
#
# $DRXTM161
# $DRXTM161$type
# [1] "numeric"
#
# $DRXTM161$mean
# [1] 1.230925
#
# $DRXTM161$median
# [1] 1.008
#
# $DRXTM161$minimum
# [1] 0
#
# $DRXTM161$maximum
# [1] 22.88
#
# $DRXTM161$std_dev
# [1] 0.9523192
#
#
# $DRXTM181
# $DRXTM181$type
# [1] "numeric"
#
# $DRXTM181$mean
# [1] 27.24634
#
# $DRXTM181$median
# [1] 23.857
#
# $DRXTM181$minimum
# [1] 0
#
# $DRXTM181$maximum
# [1] 328.836
#
# $DRXTM181$std_dev
# [1] 17.01203
#
#
# $DRXTM201
# $DRXTM201$type
# [1] "numeric"
#
# $DRXTM201$mean
# [1] 0.2706865
#
# $DRXTM201$median
# [1] 0.202
#
# $DRXTM201$minimum
# [1] 0
#
# $DRXTM201$maximum
# [1] 18.119
#
# $DRXTM201$std_dev
# [1] 0.2816769
#
#
# $DRXTM221
# $DRXTM221$type
# [1] "numeric"
#
# $DRXTM221$mean
# [1] 0.03425339
#
# $DRXTM221$median
# [1] 0.007
#
# $DRXTM221$minimum
# [1] 0
#
# $DRXTM221$maximum
# [1] 25.315
#
# $DRXTM221$std_dev
# [1] 0.1769814
#
#
# $DRXTP182
# $DRXTP182$type
# [1] "numeric"
#
# $DRXTP182$mean
# [1] 15.93187
#
# $DRXTP182$median
# [1] 13.452
#
# $DRXTP182$minimum
# [1] 0
#
# $DRXTP182$maximum
# [1] 195.387
#
# $DRXTP182$std_dev
# [1] 11.13077
#
#
# $DRXTP183
# $DRXTP183$type
# [1] "numeric"
#
# $DRXTP183$mean
# [1] 1.622135
#
# $DRXTP183$median
# [1] 1.31
#
# $DRXTP183$minimum
# [1] 0
#
# $DRXTP183$maximum
# [1] 38.127
#
# $DRXTP183$std_dev
# [1] 1.267191
#
#
# $DRXTP184
# $DRXTP184$type
# [1] "numeric"
#
# $DRXTP184$mean
# [1] 0.01092038
#
# $DRXTP184$median
# [1] 0
#
# $DRXTP184$minimum
# [1] 0
#
# $DRXTP184$maximum
# [1] 0.927
#
# $DRXTP184$std_dev
# [1] 0.03720861
#
#
# $DRXTP204
# $DRXTP204$type
# [1] "numeric"
#
# $DRXTP204$mean
# [1] 0.1496702
#
# $DRXTP204$median
# [1] 0.113
#
# $DRXTP204$minimum
# [1] 0
#
# $DRXTP204$maximum
# [1] 3.008
#
# $DRXTP204$std_dev
# [1] 0.1376574
#
#
# $DRXTP205
# $DRXTP205$type
# [1] "numeric"
#
# $DRXTP205$mean
# [1] 0.03816722
#
# $DRXTP205$median
# [1] 0.006
#
# $DRXTP205$minimum
# [1] 0
#
# $DRXTP205$maximum
# [1] 4.114
#
# $DRXTP205$std_dev
# [1] 0.1343312
#
#
# $DRXTP225
# $DRXTP225$type
# [1] "numeric"
#
# $DRXTP225$mean
# [1] 0.02252839
#
# $DRXTP225$median
# [1] 0.011
#
# $DRXTP225$minimum
# [1] 0
#
# $DRXTP225$maximum
# [1] 2.427
#
# $DRXTP225$std_dev
# [1] 0.04893982
#
#
# $DRXTP226
# $DRXTP226$type
# [1] "numeric"
#
# $DRXTP226$mean
# [1] 0.07379558
#
# $DRXTP226$median
# [1] 0.017
#
# $DRXTP226$minimum
# [1] 0
#
# $DRXTP226$maximum
# [1] 8.717
#
# $DRXTP226$std_dev
# [1] 0.2073922
#
#
# $DRD320GW
# $DRD320GW$type
# [1] "numeric"
#
# $DRD320GW$mean
# [1] 1098.044
#
# $DRD320GW$median
# [1] 826
#
# $DRD320GW$minimum
# [1] 0
#
# $DRD320GW$maximum
# [1] 16726.5
#
# $DRD320GW$std_dev
# [1] 1165.418

# %% [markdown]
# ### some discussion:
#
# By the mean-median relationship: most variables have a greater mean than median, indicating that the samples are positively skewed (tails at right). For response variables, (`bp_dia_mean`) diastolic pressure is almost symmetric and the `bp_sys_mean` (systolic pressure) is little right skewed. Both don't need transformation prior to fitting the model.
#
# For other variables, the samples are balanced in gender, around 40% people are non-hispanic white, and about 20% are black (hispanic and non-hispanic). Up around 50% samples are between 18-44 years old.
#
# And due to different scales of the data, standardization prior to fitting is necessary.

# %%
hist(merge_df_cln$bp_sys_mean, breaks=30)
abline(v=130, col="red", lwd=2)
# Out:
# Plot with title "Histogram of merge_df_cln$bp_sys_mean"

# %%
hist(merge_df_cln$bp_dia_mean, breaks=30)
abline(v=80, col="red", lwd=2)
# Out:
# Plot with title "Histogram of merge_df_cln$bp_dia_mean"

# %% [markdown]
# ### construct df1 and count the number of hypertension and non-hypertension

# %%
df1 <- merge_df_cln %>% 
        mutate(hyper = ifelse((bp_sys_mean >= 140 | bp_dia_mean >= 90), 1 , 0)) %>% 
        filter(htn_aware == "No") %>% #filter with Aware
        dplyr::select(-"bp_sys_mean", -"svy_id", -"bp_dia_mean", -"htn_aware")

# %%
df1%>% 
    ggplot() +
    geom_bar(aes(x = hyper))
# Out:
# plot without title

# %% [markdown]
# unbalanced response variable. Need to adjust the sampling before training.

# %%
protein<- hist(merge_df_cln$DRXTPROT, breaks=30)
carbonhydrate<- hist(merge_df_cln$DRXTCARB, breaks=30)
# Out:
# Plot with title "Histogram of merge_df_cln$DRXTPROT"
# Plot with title "Histogram of merge_df_cln$DRXTCARB"

# %%
hist(merge_df_cln$DRXTTFAT, breaks=30)
hist(merge_df_cln$DRXTSFAT, breaks=30)
hist(merge_df_cln$DRXTMFAT, breaks=30)
# Out:
# Plot with title "Histogram of merge_df_cln$DRXTTFAT"
# Plot with title "Histogram of merge_df_cln$DRXTSFAT"
# Plot with title "Histogram of merge_df_cln$DRXTMFAT"

# %% [markdown]
# ### systolic pressure stratified by BMI

# %%
library(gridExtra)
p1 <- merge_df_cln %>%
    filter(cc_bmi == "<25") %>%
    ggplot(aes(x = DRXTPROT, y = bp_sys_mean)) + geom_point()
p2 <- merge_df_cln %>%
    filter(cc_bmi == "25 to <30") %>%
    ggplot(aes(x = DRXTPROT, y = bp_sys_mean)) + geom_point(color="red")
p3 <- merge_df_cln %>%
    filter(cc_bmi == "30 to <35") %>%
    ggplot(aes(x = DRXTPROT, y = bp_sys_mean)) + geom_point()

p4 <- merge_df_cln %>%
    filter(cc_bmi == "35+") %>%
    ggplot(aes(x = DRXTPROT, y = bp_sys_mean)) + geom_point(color="red")

# Arrange the plots in a 2x2 grid
grid.arrange(p1, p2, p3, p4, ncol = 2)
# Out:
# Attaching package: 'gridExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
# plot without title

# %% [markdown]
# ### diastolic pressure stratified by BMI

# %%
p1 <- merge_df_cln %>%
    filter(cc_bmi == "<25") %>%
    ggplot(aes(x = DRXTPROT, y = bp_dia_mean)) + geom_point()
p2 <- merge_df_cln %>%
    filter(cc_bmi == "25 to <30") %>%
    ggplot(aes(x = DRXTPROT, y = bp_dia_mean)) + geom_point(color="red")
p3 <- merge_df_cln %>%
    filter(cc_bmi == "30 to <35") %>%
    ggplot(aes(x = DRXTPROT, y = bp_dia_mean)) + geom_point()
p4 <- merge_df_cln %>%
    filter(cc_bmi == "35+") %>%
    ggplot(aes(x = DRXTPROT, y = bp_dia_mean)) + geom_point(color="red")
grid.arrange(p1, p2, p3, p4, ncol = 2)
# Out:
# plot without title

# %% [markdown]
# ### Responses stratified by gender

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_dia_mean, color=as.factor(demo_gender))) + geom_histogram(bins = 40)
# Out:
# plot without title

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_sys_mean, color=as.factor(demo_gender))) + geom_histogram(bins = 40)
# Out:
# plot without title

# %% [markdown]
# ### responses stratified by age categories

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_sys_mean)) + geom_histogram(bins = 40) + facet_wrap("demo_age_cat")
# Out:
# plot without title

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_dia_mean)) + geom_histogram(bins = 40) + facet_wrap("demo_age_cat")
# Out:
# plot without title

# %% [markdown]
# ### responses stratified by race

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_sys_mean)) + geom_histogram(bins = 40) + facet_wrap("demo_race")
# Out:
# plot without title

# %%
ggplot(data = merge_df_cln, mapping=aes(x= bp_dia_mean)) + geom_histogram(bins = 40) + facet_wrap("demo_race")
# Out:
# plot without title

# %% [markdown]
#  plot hypertension counts by 140/90 and no awareness

# %% [markdown]
# # T Test Analysis

# %% [markdown]
# ## Separate by Year

# %%
subsets <- split(merge_df_cln, merge_df_cln$svy_year)

# %% [markdown]
# ## T test for each variable

# %%
# Define the list of survey years in order
survey_years <- c("1999-2000", "2001-2002", "2003-2004", "2005-2006", "2007-2008", 
                  "2009-2010", "2011-2012", "2013-2014", "2015-2016", "2017-2020")

# Initialize an empty list to store t-test results
t_test_results <- list()

# Loop through consecutive survey years and perform t-tests
for (i in 1:(length(survey_years) - 1)) {
  year1 <- survey_years[i]
  year2 <- survey_years[i + 1]
  
  # Extract subsets for each year
  df1 <- subsets[[year1]]
  df2 <- subsets[[year2]]
  
  # Perform independent t-test on bp_sys_mean
  t_test <- t.test(df1$bp_sys_mean, df2$bp_sys_mean, var.equal = FALSE)
  
  # Store results
  t_test_results[[paste(year1, "vs", year2)]] <- list(
    "t_statistic" = t_test$statistic,
    "p_value" = t_test$p.value
  )
}

# Convert results to a data frame for better visualization
t_test_df <- do.call(rbind, lapply(names(t_test_results), function(x) {
  data.frame(Comparison = x, 
             t_statistic = t_test_results[[x]]$t_statistic, 
             p_value = t_test_results[[x]]$p_value)
}))

# Print the results
print(t_test_df)
# Out:
#                Comparison t_statistic      p_value
# t  1999-2000 vs 2001-2002   4.3768740 1.218126e-05
# t1 2001-2002 vs 2003-2004  -0.9206637 3.572511e-01
# t2 2003-2004 vs 2005-2006   3.8809833 1.048060e-04
# t3 2005-2006 vs 2007-2008  -0.8393776 4.012789e-01
# t4 2007-2008 vs 2009-2010   4.4772111 7.639059e-06
# t5 2009-2010 vs 2011-2012  -1.9985203 4.568696e-02
# t6 2011-2012 vs 2013-2014   1.4965075 1.345540e-01
# t7 2013-2014 vs 2015-2016  -7.2225893 5.472971e-13
# t8 2015-2016 vs 2017-2020  -1.3285793 1.840144e-01

# %%
# Define the ordered list of survey years
survey_years <- c("1999-2000", "2001-2002", "2003-2004", "2005-2006", "2007-2008", 
                  "2009-2010", "2011-2012", "2013-2014", "2015-2016", "2017-2020")

# Initialize an empty list to store t-test results
t_test_results <- list()

# Loop through all unique pairs of years and perform t-tests
for (i in 1:(length(survey_years) - 1)) {
  for (j in (i + 1):length(survey_years)) {
    year1 <- survey_years[i]
    year2 <- survey_years[j]
    
    # Extract subsets for each year
    df1 <- subsets[[year1]]
    df2 <- subsets[[year2]]
    
    # Perform independent t-test on bp_sys_mean
    t_test <- t.test(df1$bp_sys_mean, df2$bp_sys_mean, var.equal = FALSE)
    
    # Determine direction (Increase or Decrease)
    direction <- ifelse(t_test$statistic > 0, "Increase", "Decrease")
    
    # Check significance level (p < 0.05 → TRUE, else FALSE)
    significant <- t_test$p.value < 0.05
    
    # Store results
    t_test_results[[paste(year1, "vs", year2)]] <- list(
      "Direction" = direction,
      "Significant" = significant
    )
  }
}

# Convert results to a data frame for better visualization
t_test_df <- do.call(rbind, lapply(names(t_test_results), function(x) {
  data.frame(Comparison = x, 
             Direction = t_test_results[[x]]$Direction, 
             Significant = t_test_results[[x]]$Significant)
}))

# Print the results
print(t_test_df)
# Out:
#                 Comparison Direction Significant
# t   1999-2000 vs 2001-2002  Increase        TRUE
# t1  1999-2000 vs 2003-2004  Increase        TRUE
# t2  1999-2000 vs 2005-2006  Increase        TRUE
# t3  1999-2000 vs 2007-2008  Increase        TRUE
# t4  1999-2000 vs 2009-2010  Increase        TRUE
# t5  1999-2000 vs 2011-2012  Increase        TRUE
# t6  1999-2000 vs 2013-2014  Increase        TRUE
# t7  1999-2000 vs 2015-2016  Increase        TRUE
# t8  1999-2000 vs 2017-2020  Increase        TRUE
# t9  2001-2002 vs 2003-2004  Decrease       FALSE
# t10 2001-2002 vs 2005-2006  Increase        TRUE
# t11 2001-2002 vs 2007-2008  Increase        TRUE
# t12 2001-2002 vs 2009-2010  Increase        TRUE
# t13 2001-2002 vs 2011-2012  Increase        TRUE
# t14 2001-2002 vs 2013-2014  Increase        TRUE
# t15 2001-2002 vs 2015-2016  Decrease       FALSE
# t16 2001-2002 vs 2017-2020  Decrease       FALSE
# t17 2003-2004 vs 2005-2006  Increase        TRUE
# t18 2003-2004 vs 2007-2008  Increase        TRUE
# t19 2003-2004 vs 2009-2010  Increase        TRUE
# t20 2003-2004 vs 2011-2012  Increase        TRUE
# t21 2003-2004 vs 2013-2014  Increase        TRUE
# t22 2003-2004 vs 2015-2016  Increase       FALSE
# t23 2003-2004 vs 2017-2020  Decrease       FALSE
# t24 2005-2006 vs 2007-2008  Decrease       FALSE
# t25 2005-2006 vs 2009-2010  Increase        TRUE
# t26 2005-2006 vs 2011-2012  Increase       FALSE
# t27 2005-2006 vs 2013-2014  Increase        TRUE
# t28 2005-2006 vs 2015-2016  Decrease        TRUE
# t29 2005-2006 vs 2017-2020  Decrease        TRUE
# t30 2007-2008 vs 2009-2010  Increase        TRUE
# t31 2007-2008 vs 2011-2012  Increase        TRUE
# t32 2007-2008 vs 2013-2014  Increase        TRUE
# t33 2007-2008 vs 2015-2016  Decrease        TRUE
# t34 2007-2008 vs 2017-2020  Decrease        TRUE
# t35 2009-2010 vs 2011-2012  Decrease        TRUE
# t36 2009-2010 vs 2013-2014  Decrease       FALSE
# t37 2009-2010 vs 2015-2016  Decrease        TRUE
# t38 2009-2010 vs 2017-2020  Decrease        TRUE
# t39 2011-2012 vs 2013-2014  Increase       FALSE
# t40 2011-2012 vs 2015-2016  Decrease        TRUE
# t41 2011-2012 vs 2017-2020  Decrease        TRUE
# t42 2013-2014 vs 2015-2016  Decrease        TRUE
# t43 2013-2014 vs 2017-2020  Decrease        TRUE
# t44 2015-2016 vs 2017-2020  Decrease       FALSE

# %%
# Define the ordered list of survey years
survey_years <- c("1999-2000", "2001-2002", "2003-2004", "2005-2006", "2007-2008", 
                  "2009-2010", "2011-2012", "2013-2014", "2015-2016", "2017-2020")

# Define the list of variables for t-tests
variables <- c("demo_age_years", "DRXTMOIS","DRXTCARB", 
               "DRDTSODI", "DRXTCAFF", "DRXTFOLA", "DRXTVC", "DRXTCALC")

# Initialize an empty list to store t-test results
t_test_results <- list()

# Loop through all unique pairs of years and perform t-tests for each variable
for (i in 1:(length(survey_years) - 1)) {
  for (j in (i + 1):length(survey_years)) {
    year1 <- survey_years[i]
    year2 <- survey_years[j]
    
    # Extract subsets for each year
    df1 <- subsets[[year1]]
    df2 <- subsets[[year2]]
    
    # Loop through each variable and perform the t-test
    for (var in variables) {
      # Ensure the variable exists in both datasets before running the test
      if (var %in% names(df1) & var %in% names(df2)) {
        # Perform independent t-test on the variable
        t_test <- t.test(df1[[var]], df2[[var]], var.equal = FALSE)
        
        # Determine direction (Increase or Decrease)
        direction <- ifelse(t_test$statistic > 0, "Increase", "Decrease")
        
        # Check significance level (p < 0.05 → TRUE, else FALSE)
        significant <- t_test$p.value < 0.05
        
        # Store results
        t_test_results[[paste(year1, "vs", year2, "-", var)]] <- list(
          "Variable" = var,
          "Direction" = direction,
          "Significant" = significant
        )
      }
    }
  }
}

# Convert results to a data frame for better visualization
t_test_df <- do.call(rbind, lapply(names(t_test_results), function(x) {
  data.frame(Comparison = x, 
             Variable = t_test_results[[x]]$Variable, 
             Direction = t_test_results[[x]]$Direction, 
             Significant = t_test_results[[x]]$Significant)
}))

# Print the results
print(t_test_df)
# Out:
#                                   Comparison       Variable Direction
# t    1999-2000 vs 2001-2002 - demo_age_years demo_age_years  Increase
# t1         1999-2000 vs 2001-2002 - DRXTMOIS       DRXTMOIS  Decrease
# t2         1999-2000 vs 2001-2002 - DRXTCARB       DRXTCARB  Decrease
# t3         1999-2000 vs 2001-2002 - DRDTSODI       DRDTSODI  Decrease
# t4         1999-2000 vs 2001-2002 - DRXTCAFF       DRXTCAFF  Increase
# t5         1999-2000 vs 2001-2002 - DRXTFOLA       DRXTFOLA  Decrease
# t6           1999-2000 vs 2001-2002 - DRXTVC         DRXTVC  Increase
# t7         1999-2000 vs 2001-2002 - DRXTCALC       DRXTCALC  Decrease
# t8   1999-2000 vs 2003-2004 - demo_age_years demo_age_years  Increase
# t9         1999-2000 vs 2003-2004 - DRXTMOIS       DRXTMOIS  Decrease
# t10        1999-2000 vs 2003-2004 - DRXTCARB       DRXTCARB  Decrease
# t11        1999-2000 vs 2003-2004 - DRDTSODI       DRDTSODI  Decrease
# t12        1999-2000 vs 2003-2004 - DRXTCAFF       DRXTCAFF  Increase
# t13        1999-2000 vs 2003-2004 - DRXTFOLA       DRXTFOLA  Decrease
# t14          1999-2000 vs 2003-2004 - DRXTVC         DRXTVC  Increase
# t15        1999-2000 vs 2003-2004 - DRXTCALC       DRXTCALC  Decrease
# t16  1999-2000 vs 2005-2006 - demo_age_years demo_age_years  Increase
# t17        1999-2000 vs 2005-2006 - DRXTMOIS       DRXTMOIS  Decrease
# t18        1999-2000 vs 2005-2006 - DRXTCARB       DRXTCARB  Decrease
# t326         2011-2012 vs 2015-2016 - DRXTVC         DRXTVC  Increase
# t327       2011-2012 vs 2015-2016 - DRXTCALC       DRXTCALC  Increase
# t328 2011-2012 vs 2017-2020 - demo_age_years demo_age_years  Decrease
# t329       2011-2012 vs 2017-2020 - DRXTMOIS       DRXTMOIS  Increase
# t330       2011-2012 vs 2017-2020 - DRXTCARB       DRXTCARB  Increase
# t331       2011-2012 vs 2017-2020 - DRDTSODI       DRDTSODI  Increase
# t332       2011-2012 vs 2017-2020 - DRXTCAFF       DRXTCAFF  Increase
# t333       2011-2012 vs 2017-2020 - DRXTFOLA       DRXTFOLA  Increase
# t334         2011-2012 vs 2017-2020 - DRXTVC         DRXTVC  Increase
# t335       2011-2012 vs 2017-2020 - DRXTCALC       DRXTCALC  Increase
# t336 2013-2014 vs 2015-2016 - demo_age_years demo_age_years  Decrease
# t337       2013-2014 vs 2015-2016 - DRXTMOIS       DRXTMOIS  Increase
# t338       2013-2014 vs 2015-2016 - DRXTCARB       DRXTCARB  Increase
# t339       2013-2014 vs 2015-2016 - DRDTSODI       DRDTSODI  Increase
# t340       2013-2014 vs 2015-2016 - DRXTCAFF       DRXTCAFF  Increase
# t341       2013-2014 vs 2015-2016 - DRXTFOLA       DRXTFOLA  Increase
# t342         2013-2014 vs 2015-2016 - DRXTVC         DRXTVC  Increase
# t343       2013-2014 vs 2015-2016 - DRXTCALC       DRXTCALC  Increase
# t344 2013-2014 vs 2017-2020 - demo_age_years demo_age_years  Decrease
# t345       2013-2014 vs 2017-2020 - DRXTMOIS       DRXTMOIS  Increase
# t346       2013-2014 vs 2017-2020 - DRXTCARB       DRXTCARB  Increase
# t347       2013-2014 vs 2017-2020 - DRDTSODI       DRDTSODI  Increase
# t348       2013-2014 vs 2017-2020 - DRXTCAFF       DRXTCAFF  Increase
# t349       2013-2014 vs 2017-2020 - DRXTFOLA       DRXTFOLA  Increase
# t350         2013-2014 vs 2017-2020 - DRXTVC         DRXTVC  Increase
# t351       2013-2014 vs 2017-2020 - DRXTCALC       DRXTCALC  Increase
# t352 2015-2016 vs 2017-2020 - demo_age_years demo_age_years  Decrease
# t353       2015-2016 vs 2017-2020 - DRXTMOIS       DRXTMOIS  Decrease
# t354       2015-2016 vs 2017-2020 - DRXTCARB       DRXTCARB  Increase
# t355       2015-2016 vs 2017-2020 - DRDTSODI       DRDTSODI  Increase
# t356       2015-2016 vs 2017-2020 - DRXTCAFF       DRXTCAFF  Decrease
# t357       2015-2016 vs 2017-2020 - DRXTFOLA       DRXTFOLA  Increase
# t358         2015-2016 vs 2017-2020 - DRXTVC         DRXTVC  Increase
# t359       2015-2016 vs 2017-2020 - DRXTCALC       DRXTCALC  Increase
#      Significant
# t           TRUE
# t1          TRUE
# t2          TRUE
# t3         FALSE
# t4          TRUE
# t5          TRUE
# t6         FALSE
# t7          TRUE
# t8         FALSE
# t9          TRUE
# t10        FALSE
# t11         TRUE
# t12         TRUE
# t13         TRUE
# t14         TRUE
# t15         TRUE
# t16         TRUE
# t17         TRUE
# t18        FALSE
# t19         TRUE
# t20         TRUE
# t21         TRUE
# t22         TRUE
# t23         TRUE
# t24         TRUE
# t25         TRUE
# t26         TRUE
# t27        FALSE
# t28        FALSE
# t29         TRUE
# t30         TRUE
# t31         TRUE
# t32         TRUE
# t33         TRUE
# t34        FALSE
# t35         TRUE
# t36         TRUE
# t37         TRUE
# t38         TRUE
# t39         TRUE
# t40        FALSE
# t41         TRUE
# t42        FALSE
# t43         TRUE
# t44         TRUE
# t45         TRUE
# t46         TRUE
# t47         TRUE
# t48        FALSE
# t49         TRUE
# t50         TRUE
# t51         TRUE
# t52         TRUE
# t53         TRUE
# t54         TRUE
# t55         TRUE
# t56         TRUE
# t57         TRUE
# t58         TRUE
# t59         TRUE
# t60         TRUE
# t61         TRUE
# t62         TRUE
# t63         TRUE
# t64         TRUE
# t65         TRUE
# t66         TRUE
# t67         TRUE
# t68         TRUE
# t69        FALSE
# t70         TRUE
# t71         TRUE
# t72         TRUE
# t73        FALSE
# t74        FALSE
# t75        FALSE
# t76         TRUE
# t77         TRUE
# t78         TRUE
# t79        FALSE
# t80        FALSE
# t81         TRUE
# t82         TRUE
# t83         TRUE
# t84        FALSE
# t85         TRUE
# t86         TRUE
# t87         TRUE
# t88         TRUE
# t89         TRUE
# t90         TRUE
# t91        FALSE
# t92         TRUE
# t93         TRUE
# t94         TRUE
# t95         TRUE
# t96         TRUE
# t97         TRUE
# t98         TRUE
# t99         TRUE
# t100        TRUE
# t101        TRUE
# t102        TRUE
# t103        TRUE
# t104        TRUE
# t105        TRUE
# t106        TRUE
# t107        TRUE
# t108        TRUE
# t109       FALSE
# t110        TRUE
# t111        TRUE
# t112        TRUE
# t113        TRUE
# t114        TRUE
# t115        TRUE
# t116       FALSE
# t117        TRUE
# t118        TRUE
# t119        TRUE
# t120        TRUE
# t121        TRUE
# t122        TRUE
# t123        TRUE
# t124        TRUE
# t125        TRUE
# t126        TRUE
# t127        TRUE
# t128        TRUE
# t129        TRUE
# t130        TRUE
# t131        TRUE
# t132        TRUE
# t133        TRUE
# t134        TRUE
# t135        TRUE
# t136        TRUE
# t137        TRUE
# t138       FALSE
# t139       FALSE
# t140       FALSE
# t141       FALSE
# t142       FALSE
# t143        TRUE
# t144        TRUE
# t145        TRUE
# t146        TRUE
# t147       FALSE
# t148       FALSE
# t149       FALSE
# t150        TRUE
# t151        TRUE
# t152        TRUE
# t153        TRUE
# t154        TRUE
# t155        TRUE
# t156       FALSE
# t157       FALSE
# t158        TRUE
# t159        TRUE
# t160       FALSE
# t161        TRUE
# t162       FALSE
# t163        TRUE
# t164        TRUE
# t165        TRUE
# t166        TRUE
# t167        TRUE
# t168       FALSE
# t169        TRUE
# t170        TRUE
# t171        TRUE
# t172        TRUE
# t173       FALSE
# t174        TRUE
# t175        TRUE
# t176        TRUE
# t177        TRUE
# t178        TRUE
# t179        TRUE
# t180        TRUE
# t181       FALSE
# t182        TRUE
# t183        TRUE
# t184        TRUE
# t185        TRUE
# t186        TRUE
# t187        TRUE
# t188        TRUE
# t189        TRUE
# t190        TRUE
# t191        TRUE
# t192        TRUE
# t193        TRUE
# t194        TRUE
# t195        TRUE
# t196        TRUE
# t197       FALSE
# t198        TRUE
# t199       FALSE
# t200        TRUE
# t201       FALSE
# t202        TRUE
# t203       FALSE
# t204       FALSE
# t205       FALSE
# t206        TRUE
# t207        TRUE
# t208        TRUE
# t209       FALSE
# t210       FALSE
# t211        TRUE
# t212        TRUE
# t213        TRUE
# t214        TRUE
# t215        TRUE
# t216        TRUE
# t217       FALSE
# t218        TRUE
# t219        TRUE
# t220        TRUE
# t221       FALSE
# t222        TRUE
# t223        TRUE
# t224        TRUE
# t225       FALSE
# t226        TRUE
# t227        TRUE
# t228        TRUE
# t229       FALSE
# t230        TRUE
# t231       FALSE
# t232        TRUE
# t233       FALSE
# t234        TRUE
# t235       FALSE
# t236        TRUE
# t237        TRUE
# t238        TRUE
# t239       FALSE
# t240        TRUE
# t241        TRUE
# t242        TRUE
# t243        TRUE
# t244       FALSE
# t245        TRUE
# t246       FALSE
# t247        TRUE
# t248        TRUE
# t249        TRUE
# t250        TRUE
# t251        TRUE
# t252        TRUE
# t253        TRUE
# t254       FALSE
# t255        TRUE
# t256        TRUE
# t257        TRUE
# t258       FALSE
# t259        TRUE
# t260        TRUE
# t261       FALSE
# t262        TRUE
# t263        TRUE
# t264        TRUE
# t265       FALSE
# t266        TRUE
# t267        TRUE
# t268        TRUE
# t269       FALSE
# t270        TRUE
# t271       FALSE
# t272       FALSE
# t273       FALSE
# t274        TRUE
# t275        TRUE
# t276        TRUE
# t277        TRUE
# t278        TRUE
# t279       FALSE
# t280        TRUE
# t281        TRUE
# t282        TRUE
# t283        TRUE
# t284        TRUE
# t285        TRUE
# t286       FALSE
# t287        TRUE
# t288        TRUE
# t289       FALSE
# t290       FALSE
# t291       FALSE
# t292        TRUE
# t293       FALSE
# t294        TRUE
# t295        TRUE
# t296       FALSE
# t297       FALSE
# t298        TRUE
# t299       FALSE
# t300        TRUE
# t301        TRUE
# t302        TRUE
# t303        TRUE
# t304        TRUE
# t305       FALSE
# t306        TRUE
# t307       FALSE
# t308        TRUE
# t309        TRUE
# t310        TRUE
# t311        TRUE
# t312       FALSE
# t313        TRUE
# t314        TRUE
# t315       FALSE
# t316       FALSE
# t317        TRUE
# t318        TRUE
# t319       FALSE
# t320        TRUE
# t321        TRUE
# t322        TRUE
# t323        TRUE
# t324       FALSE
# t325        TRUE
# t326        TRUE
# t327        TRUE
# t328        TRUE
# t329        TRUE
# t330        TRUE
# t331        TRUE
# t332       FALSE
# t333        TRUE
# t334        TRUE
# t335        TRUE
# t336        TRUE
# t337       FALSE
# t338        TRUE
# t339       FALSE
# t340       FALSE
# t341        TRUE
# t342       FALSE
# t343        TRUE
# t344        TRUE
# t345       FALSE
# t346        TRUE
# t347        TRUE
# t348       FALSE
# t349        TRUE
# t350        TRUE
# t351        TRUE
# t352        TRUE
# t353       FALSE
# t354       FALSE
# t355        TRUE
# t356       FALSE
# t357        TRUE
# t358       FALSE
# t359       FALSE

# %% [markdown]
# ## EDA For Variable

# %%
# Define the list of survey years
survey_years <- c("1999-2000", "2001-2002", "2003-2004", "2005-2006", "2007-2008", 
                  "2009-2010", "2011-2012", "2013-2014", "2015-2016", "2017-2020")

# Define the list of variables for line plots
variables <- c("demo_age_years", "DRXTMOIS", "DRXTCARB", "DRDTSODI", 
               "DRXTCAFF", "DRXTFOLA", "DRXTVC", "DRXTCALC")

# Create an empty data frame to store mean values
mean_df <- data.frame(Survey_Year = rep(survey_years, each = length(variables)),
                      Variable = rep(variables, times = length(survey_years)),
                      Mean_Value = NA)

# Compute mean for each variable across survey years
for (year in survey_years) {
  df <- subsets[[year]]
  for (var in variables) {
    if (var %in% names(df)) {
      mean_value <- mean(df[[var]], na.rm = TRUE)
      mean_df
Survey_Year == year & mean_df$Variable == var] <- mean_value
    }
  }
}

# Convert survey years to factor with proper ordering
mean_df
Survey_Year, levels = survey_years)

# Initialize an empty list to store plots
plot_list <- list()

# Generate and store line plots for each variable
for (var in variables) {
  plot_data <- subset(mean_df, Variable == var)
  
  p <- ggplot(plot_data, aes(x = Survey_Year, y = Mean_Value, group = 1)) +
    geom_line(color = "blue") +
    geom_point(color = "red") +
    labs(title = paste("Mean", var, "Across Survey Years"),
         x = "Survey Year", 
         y = paste("Mean", var)) +
    theme_minimal() +
    theme(
        axis.text.x = element_text(size = 14, angle = 45, hjust = 1),
        axis.text.y = element_text(size = 14),
        axis.title.x = element_text(size = 16),  # X-axis title larger
        axis.title.y = element_text(size = 16),  # Y-axis title larger
        plot.title = element_text(size = 18, face = "bold")  # Title larger & bold
      )
  
  # Store the plot in the list with the variable name
  plot_list[[var]] <- p
}

# %%
options(repr.plot.width = 15, repr.plot.height = 10)
plot_list[["demo_age_years"]]

# %%
# Define the list of survey years
survey_years <- c("1999-2000", "2001-2002", "2003-2004", "2005-2006", "2007-2008", 
                  "2009-2010", "2011-2012", "2013-2014", "2015-2016", "2017-2020")

# Initialize an empty data frame to store counts
age_cat_counts <- data.frame(Survey_Year = character(), demo_age_cat = character(), Count = integer())

# Loop through each survey year and count age categories
for (year in survey_years) {
  df <- subsets[[year]]
  
  # Count occurrences of each age category
  age_counts <- df %>%
    group_by(demo_age_cat) %>%
    summarise(Count = n()) %>%
    mutate(Survey_Year = year)  # Add survey year column
  
  # Append to the main data frame
  age_cat_counts <- rbind(age_cat_counts, age_counts)
}

# Convert survey years and categories to factors for proper ordering
age_cat_counts
Survey_Year, levels = survey_years)
age_cat_counts
demo_age_cat, 
                                      levels = c("18 to 44", "45 to 64", "65 to 74", "75+"))

# Create grouped bar plot
p <- ggplot(age_cat_counts, aes(x = Survey_Year, y = Count, fill = demo_age_cat)) +
  geom_bar(stat = "identity", position = "dodge") +  # Grouped bars
  labs(title = "Distribution of Age Categories Across Survey Years",
       x = "Survey Year", 
       y = "Count",
       fill = "Age Category") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1, size = 12),  # Rotate x-axis labels
        axis.title.x = element_text(size = 14),
        axis.title.y = element_text(size = 14),
        plot.title = element_text(size = 16, face = "bold"),
        legend.text = element_text(size = 14),
        legend.title = element_text(size = 16, face = "bold"),
        legend.key.size = unit(1.5, "cm"))

# Print the plot
print(p)
